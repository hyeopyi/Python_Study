# %% [markdown]
# # DataFrame

# %% [markdown]
# - 2차원 배열
# - 행과 열로 구성

# %%
import pandas as pd

# %%
# Dictionary를 이용한 DataFrame 생성
dict_data = {"c0":[1,2,3], "c1":[4,5,6], "c2":[7,8,9], "c3": [10, 11, 12], "c4":[13,14,15]}
dict_data
# Out:
# {'c0': [1, 2, 3],
#  'c1': [4, 5, 6],
#  'c2': [7, 8, 9],
#  'c3': [10, 11, 12],
#  'c4': [13, 14, 15]}

# %%
df = pd.DataFrame(dict_data)
df
# Out:
#    c0  c1  c2  c3  c4
# 0   1   4   7  10  13
# 1   2   5   8  11  14
# 2   3   6   9  12  15

# %%
# List를 이용한 DataFrame 생성
df = pd.DataFrame([[15, "남", "덕영중"], [17, "여", "수리중"]], index=["준서", "예은"], columns=["나이", "성별", "학교"])
df
# Out:
#     나이 성별   학교
# 준서  15  남  덕영중
# 예은  17  여  수리중

# %%
# 행과 열 이름 변경하기
print(df.index)
print(df.columns)
# Out:
# Index(['준서', '예은'], dtype='object')
# Index(['나이', '성별', '학교'], dtype='object')

# %%
# 행 인덱스, 열 이름 변경하기 - 1
df.index = ["학생1", "학생2"]
df.columns = ["연령", "남녀", "소속"]
df
# Out:
#      연령 남녀   소속
# 학생1  15  남  덕영중
# 학생2  17  여  수리중

# %%
# List를 이용한 DataFrame 생성
df = pd.DataFrame([[15, "남", "덕영중"], [17, "여", "수리중"]], index=["준서", "예은"], columns=["나이", "성별", "학교"])
df
# Out:
#     나이 성별   학교
# 준서  15  남  덕영중
# 예은  17  여  수리중

# %%
df.rename(columns={"나이":"연령", "성별":"남녀", "학교":"소속"}, inplace=True)
df
# Out:
#     연령 남녀   소속
# 준서  15  남  덕영중
# 예은  17  여  수리중

# %%
# 행 이름 변경하기
# df의 행 인덱스 중에서 준서를 학생1로 예은을 학생2로 바꾸기
df.rename(index={"준서":"학생1", "예은":"학생2"}, inplace=True)
df
# Out:
#      연령 남녀   소속
# 학생1  15  남  덕영중
# 학생2  17  여  수리중

# %%
# Dictionary를 이용한 DataFrame 생성
df = pd.DataFrame({"수학":[90,80,70], "영어":[98,89,95], "음악":[85,95,100], "체육": [100,90,90]},
                   index=["서준", "우현", "인아"])
print(df)

# List를 이용한 DataFrame 생성
df = pd.DataFrame([[90, 98, 85, 100], [80, 89, 95, 90], [70, 95, 100, 90]],
               index=["서준", "우현", "인아"], columns=["수학", "영어", "음악", "체육"])
df
# Out:
#     수학  영어   음악   체육
# 서준  90  98   85  100
# 우현  80  89   95   90
# 인아  70  95  100   90
#     수학  영어   음악   체육
# 서준  90  98   85  100
# 우현  80  89   95   90
# 인아  70  95  100   90

# %% [markdown]
# ## 행 삭제

# %%
df2 = df.copy()

# %%
df2
# Out:
#     수학  영어   음악   체육
# 서준  90  98   85  100
# 우현  80  89   95   90
# 인아  70  95  100   90

# %%
# df2의 index가 우현인 1개행을 삭제
df2.drop("우현", axis = 0, inplace=True)

# %%
df2
# Out:
#     수학  영어   음악   체육
# 서준  90  98   85  100
# 인아  70  95  100   90

# %%
df3 = df.copy()

# %%
df3
# Out:
#     수학  영어   음악   체육
# 서준  90  98   85  100
# 우현  80  89   95   90
# 인아  70  95  100   90

# %%
# df3의 index가 우현과 인아 인 2개행을 삭제
df3.drop(["우현", "인아"], axis=0, inplace=True)

# %%
df3
# Out:
#     수학  영어  음악   체육
# 서준  90  98  85  100

# %%
# 열 삭제
df4 = df.copy()

# %%
df4
# Out:
#     수학  영어   음악   체육
# 서준  90  98   85  100
# 우현  80  89   95   90
# 인아  70  95  100   90

# %%
# df4의 수학 1개 열을 삭제
df4.drop("수학", axis=1, inplace=True)
df4
# Out:
#     영어   음악   체육
# 서준  98   85  100
# 우현  89   95   90
# 인아  95  100   90

# %%
# df5의 영어와ㅣ 음악 2개열을 삭제
df5 = df.copy()
print(df5)
df5.drop(["영어", "음악"], axis=1, inplace=True)
df5
# Out:
#     수학  영어   음악   체육
# 서준  90  98   85  100
# 우현  80  89   95   90
# 인아  70  95  100   90
#     수학   체육
# 서준  90  100
# 우현  80   90
# 인아  70   90

# %%
# indedx가 서ㄴㅣㄴ 행ㅡ 선ㅐ
print(df.loc["서준"])
print(df.iloc[0])
# Out:
# 수학     90
# 영어     98
# 음악     85
# 체육    100
# Name: 서준, dtype: int64
# 수학     90
# 영어     98
# 음악     85
# 체육    100
# Name: 서준, dtype: int64

# %%
# 행 인덱스를 사용하여 서준과 우현 2개의 행을 선택
df.loc[["서준","우현"]]
df.iloc[:2]
# Out:
#     수학  영어  음악   체육
# 서준  90  98  85  100
# 우현  80  89  95   90

# %% [markdown]
# # 열 선택

# %%
df.수학
df["수학"]
# Out:
# 서준    90
# 우현    80
# 인아    70
# Name: 수학, dtype: int64

# %% [markdown]
# ### 범위 Slicing 활용
# - dataFrame.iloc[시작index:끝index:증가치]

# %%
# 처음부터 끝까지 2씩 index를 증가시켜서 보여주기
df.iloc[::2]
# Out:
#     수학  영어   음악   체육
# 서준  90  98   85  100
# 인아  70  95  100   90

# %%
# 0번부터 2번까지 2씩 증가시켜서 보여주기
df.iloc[0:3:2]
# Out:
#     수학  영어   음악   체육
# 서준  90  98   85  100
# 인아  70  95  100   90

# %%
# 처음부터 끝까지 -1씩 증가시켜서 보여주기 --> 순서 반전
df.iloc[::-1]
# Out:
#     수학  영어   음악   체육
# 인아  70  95  100   90
# 우현  80  89   95   90
# 서준  90  98   85  100

# %% [markdown]
# # 행과 열을 이용한 데이터 선택

# %%
df
# Out:
#     수학  영어   음악   체육
# 서준  90  98   85  100
# 우현  80  89   95   90
# 인아  70  95  100   90

# %%
# Dictionary를 이용한 DataFrame 생성
df = pd.DataFrame({"수학":[90,80,70], "영어":[98,89,95], "음악":[85,95,100], "체육": [100,90,90],
                  "이름" : ["서준", "우현", "인아"]})
df
# Out:
#    수학  영어   음악   체육  이름
# 0  90  98   85  100  서준
# 1  80  89   95   90  우현
# 2  70  95  100   90  인아

# %%
# index 만들기
df.set_index("이름", inplace=True)
df
# Out:
#     수학  영어   음악   체육
# 이름
# 서준  90  98   85  100
# 우현  80  89   95   90
# 인아  70  95  100   90

# %%
# 방법이 다양해서 이것저것 다 이해하기!
print(df.loc["서준",["음악", "체육"]])
print(df.iloc[0,2:4])
print(df.loc["서준","음악":"체육"])
print(df.loc["서준","음악":])
# Out:
# 음악     85
# 체육    100
# Name: 서준, dtype: int64
# 음악     85
# 체육    100
# Name: 서준, dtype: int64
# 음악     85
# 체육    100
# Name: 서준, dtype: int64
# 음악     85
# 체육    100
# Name: 서준, dtype: int64

# %%
df
# Out:
#     수학  영어   음악   체육
# 이름
# 서준  90  98   85  100
# 우현  80  89   95   90
# 인아  70  95  100   90

# %%
# column 추가하기
df["국어"] = 80
# df["국어"] = [10, 20, 30]
df
# Out:
#     수학  영어   음악   체육  국어
# 이름
# 서준  90  98   85  100  80
# 우현  80  89   95   90  80
# 인아  70  95  100   90  80

# %%
# row 추가하기
# df.loc["철수"] = 0
df.loc["철수"] = [10, 20, 30, 40, 50]
df
# Out:
#     수학  영어   음악   체육  국어
# 이름
# 서준  90  98   85  100  80
# 우현  80  89   95   90  80
# 인아  70  95  100   90  80
# 철수  10  20   30   40  50

# %%
# 같은 데이터 복제? 같은 느낌
df.loc["영희"] = df.loc["인아"]
df
# Out:
#     수학  영어   음악   체육  국어
# 이름
# 서준  90  98   85  100  80
# 우현  80  89   95   90  80
# 인아  70  95  100   90  80
# 철수  10  20   30   40  50
# 영희  70  95  100   90  80

# %%
# 서준의 체육 점수를 80점으로 변경하기
df.loc["서준","체육"] = 80
# df.iloc[0, 3] = 80
df
# Out:
#     수학  영어   음악  체육  국어
# 이름
# 서준  90  98   85  80  80
# 우현  80  89   95  90  80
# 인아  70  95  100  90  80
# 철수  10  20   30  40  50
# 영희  70  95  100  90  80

# %%
# 서준의 음악과 체육 점수를 50점으로 변경하기
df.loc["서준",["음악","체육"]] = 50
# df.iloc[0, 2:4] = 50
df
# Out:
#     수학  영어   음악  체육  국어
# 이름
# 서준  90  98   50  50  80
# 우현  80  89   95  90  80
# 인아  70  95  100  90  80
# 철수  10  20   30  40  50
# 영희  70  95  100  90  80

# %%
# 서준의 음악 점수를 100점 체육점수를 50점으로 변경하기
# df.loc["서준","음악"], df.loc["서준","체육"] = (100, 50)
# df.loc["서준",["음악","체육"]] = [100, 50]
df.loc["서준",["음악","체육"]] = 100, 50
df
# Out:
#     수학  영어   음악  체육  국어
# 이름
# 서준  90  98  100  50  80
# 우현  80  89   95  90  80
# 인아  70  95  100  90  80
# 철수  10  20   30  40  50
# 영희  70  95  100  90  80

# %%
# 행과 열의 위치 바꾸기
df
# Out:
#     수학  영어   음악  체육  국어
# 이름
# 서준  90  98  100  50  80
# 우현  80  89   95  90  80
# 인아  70  95  100  90  80
# 철수  10  20   30  40  50
# 영희  70  95  100  90  80

# %%
df.transpose()
# Out:
# 이름   서준  우현   인아  철수   영희
# 수학   90  80   70  10   70
# 영어   98  89   95  20   95
# 음악  100  95  100  30  100
# 체육   50  90   90  40   90
# 국어   80  80   80  50   80

# %%
df.T
# Out:
# 이름   서준  우현   인아  철수   영희
# 수학   90  80   70  10   70
# 영어   98  89   95  20   95
# 음악  100  95  100  30  100
# 체육   50  90   90  40   90
# 국어   80  80   80  50   80

# %%
# df 만들기!
df = pd.DataFrame({"c0":[1,2,3], "c1": [4,5,6], "c2": [7,8,9], "c3":[10, 11, 12], "c4":[13, 14, 15]},
 index=["r0", "r1", "r2"])
df
# Out:
#     c0  c1  c2  c3  c4
# r0   1   4   7  10  13
# r1   2   5   8  11  14
# r2   3   6   9  12  15

# %%
# 인덱스를 재설정하기
new_index = ["r0", "r1", "r2", "r3", "r4"]
ndf = df.reindex(new_index, fill_value=0)
ndf
# Out:
#     c0  c1  c2  c3  c4
# r0   1   4   7  10  13
# r1   2   5   8  11  14
# r2   3   6   9  12  15
# r3   0   0   0   0   0
# r4   0   0   0   0   0

# %%
# index 리셋시키기
ndf = df.reset_index()
ndf
# Out:
#   index  c0  c1  c2  c3  c4
# 0    r0   1   4   7  10  13
# 1    r1   2   5   8  11  14
# 2    r2   3   6   9  12  15

# %%
df
# Out:
#     c0  c1  c2  c3  c4
# r0   1   4   7  10  13
# r1   2   5   8  11  14
# r2   3   6   9  12  15

# %%
# 내림차순으로 행 인덱스 정렬
df.sort_index(ascending=False)
# Out:
#     c0  c1  c2  c3  c4
# r2   3   6   9  12  15
# r1   2   5   8  11  14
# r0   1   4   7  10  13

# %%
# 특정 값을 기준으로 정렬
df
# Out:
#     c0  c1  c2  c3  c4
# r0   1   4   7  10  13
# r1   2   5   8  11  14
# r2   3   6   9  12  15

# %%
df.sort_values(by="c1", ascending=False, inplace=True)
df
# Out:
#     c0  c1  c2  c3  c4
# r2   3   6   9  12  15
# r1   2   5   8  11  14
# r0   1   4   7  10  13

# %% [markdown]
# ### DataFrame 연산

# %%
import seaborn as sns

# %%
titanic = sns.load_dataset("titanic")

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# 기존 column 으로 새로운 column을 유추해 내는 것이 특성공학(column Engineering)

# %%
# titanic에서 age와 fare부분의 컬럼만 발췌하여 df라는 dataFrame 만들기
df = titanic[["age", "fare"]]
df
# Out:
#       age     fare
# 0    22.0   7.2500
# 1    38.0  71.2833
# 2    26.0   7.9250
# 3    35.0  53.1000
# 4    35.0   8.0500
# ..    ...      ...
# 886  27.0  13.0000
# 887  19.0  30.0000
# 888   NaN  23.4500
# 889  26.0  30.0000
# 890  32.0   7.7500
#
# [891 rows x 2 columns]

# %%
# 여러 속성 보기
df.describe()
# Out:
#               age        fare
# count  714.000000  891.000000
# mean    29.699118   32.204208
# std     14.526497   49.693429
# min      0.420000    0.000000
# 25%     20.125000    7.910400
# 50%     28.000000   14.454200
# 75%     38.000000   31.000000
# max     80.000000  512.329200

# %%
# 모든 컬럼을 10씩 증가하며 addition이라는 dataframe 생성하기
addition = df + 10
addition
# Out:
#       age     fare
# 0    32.0  17.2500
# 1    48.0  81.2833
# 2    36.0  17.9250
# 3    45.0  63.1000
# 4    45.0  18.0500
# ..    ...      ...
# 886  37.0  23.0000
# 887  29.0  40.0000
# 888   NaN  33.4500
# 889  36.0  40.0000
# 890  42.0  17.7500
#
# [891 rows x 2 columns]

# %%
# addtion과 df의 차를 구해서 subtraction이라는 dataframe 만들기
subtraction = addition - df
subtraction
# Out:
#       age  fare
# 0    10.0  10.0
# 1    10.0  10.0
# 2    10.0  10.0
# 3    10.0  10.0
# 4    10.0  10.0
# ..    ...   ...
# 886  10.0  10.0
# 887  10.0  10.0
# 888   NaN  10.0
# 889  10.0  10.0
# 890  10.0  10.0
#
# [891 rows x 2 columns]
