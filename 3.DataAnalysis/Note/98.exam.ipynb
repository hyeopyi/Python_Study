# %%
# Libarary
from bs4 import BeautifulSoup
import urllib.request as req
import pandas as pd

# Site Address
url = "https://news.daum.net/"

# urlOpen
res = req.urlopen(url)

# BeautifulSoup으로 분석하기
soup = BeautifulSoup(res, "html.parser")

# %%
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html class="os_unknown none unknown version_0" lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="always" name="referrer">
# <meta content="Daum 뉴스" property="og:author"/>
# <meta content="다음뉴스" property="og:site_name"/>
# <meta content="홈" property="og:title"/>
# <meta content="https://t1.daumcdn.net/media/img-media/mobile/meta/news.png" property="og:image"/>
# <meta content="다음뉴스" property="og:description"/>
# <meta content="https://news.daum.net/" property="og:url"/>
# <link href="https://m2.daumcdn.net/img-media/2010ci/Daum_favicon.ico" rel="shortcut icon"/>
# <title>홈 | 다음뉴스</title>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <link href="//t1.daumcdn.net/media/kraken/news/1fc755b/style.css.merged.css" rel="stylesheet" type="text/css">
# <link href="//t1.daumcdn.net/media/kraken/news/1fc755b/calendar.css.merged.css" rel="stylesheet" type="text/css"/>
# <!--[if lte IE 8]>
# ...

# %%
news = soup.select(".box_g strong > a")
titles = []
for title in news:
    #print(title.string.strip())
    titles.append(title.string.strip())

# %%
titles
# Out:
# ['MB 처남 부인, 다스 관련 9억원대 증여세 소송 2심도 승소',
#  '세계 지도자들 충격·슬픔..블링컨 미 국무 "아베 위해 기도"',
#  "'민주당 경선 개입 의혹'..전북도 전 공무원 구속영장",
#  '尹대통령·김건희 여사 고발한 시민단체.."직권 남용했다"',
#  '소수 하청노동자 파업에 대우조선 마비..노-노 갈등 비화 조짐',
#  '총격 피습 아베..최장수 총리 재임한 일본 우익 상징적 정치인',
#  '中왕이, 박진 외교장관 만나 "냉전 사고가 되살아 나는 것 막아야"',
#  '오세훈 "文, \'서해 피살\' 보고에도 지시 안했다니..충격"',
#  '박진, 日 하야시 만나 "아베 피격에 매우 충격..쾌유 기원"',
#  '"삼성, 반도체 앞선 것 같아도 실태는 달라..TSMC와 격차 벌어져"',
#  '대통령실 앞으로 간 민주당 "비선외교·대통령실 사유화 규탄"..정부·여당에 반격',
#  '베이징, 오미크론 변이에 맞서 中 본토서 첫 백신 접종 의무화',
#  '"재택근무는 노동자 권리"..네덜란드 법제화 눈앞',
#  '"최소 인원만..팬데믹이 올림픽 탄소배출량 줄였다"',
#  '"가족친화 직장환경 만들기 위해 힘쓸 것"[저출생극복제주]',
#  "尹, 장관만 원탁서 '압박면접형' 업무보고..부처 기강잡기",
#  '고리원전 찾은 산업차관.."원전 역할 무엇보다 중요"',
#  "과다노출 금지가 서울시 퀴어축제 '조건'이래..핫팬츠 안돼?",
#  '고리2호기 찾은 산업차관 "계속운전 절차 차질없는 추진 당부"',
#  '장호권 광복회장 작심 인터뷰 "무차별 의혹 제기에 굴하지 않고 반드시 개혁"',
#  '[사건의재구성]아베, 11시30분쯤 총성 울리자 쓰러져(상보)',
#  '"지리산 산악관광 열차, 공론화과정 거쳐 사업모델 찾아야"',
#  '[임병선의 메멘토 모리] 아들이 부고 기고 "악(惡)은 결국 죽는다"',
#  '[데일리 북한] 김일성 주석 사망 28주기..차분한 추모 분위기',
# ...

# %%
news_title = pd.DataFrame(titles, columns=['news_title'])
news_title.head()
# Out:
#                            news_title
# 0  MB 처남 부인, 다스 관련 9억원대 증여세 소송 2심도 승소
# 1  세계 지도자들 충격·슬픔..블링컨 미 국무 "아베 위해 기도"
# 2      '민주당 경선 개입 의혹'..전북도 전 공무원 구속영장
# 3     尹대통령·김건희 여사 고발한 시민단체.."직권 남용했다"
# 4  소수 하청노동자 파업에 대우조선 마비..노-노 갈등 비화 조짐

# %%
import pymysql
newsUpdate = creat_news("mysql+pymysql://root:qwer1234@127.0.0.1:3306/daum")
conn = newUpdate.connect()
news_title.sql(name='news'm conn=newsUpdate, if_exists='append', index=False)
